# %% [markdown]
# # Importing necessary Libraries

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation,Dropout,Conv2D,Flatten,MaxPool2D,Reshape,InputLayer
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img,img_to_array
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %% [markdown]
# # 2.Image Augmentation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/MyDrive/flowers'

# %%
train_data_gen = ImageDataGenerator(rescale = 1./255,
                             shear_range = 0.2,
                             zoom_range = 0.2,
                             horizontal_flip = True,
                             validation_split = 0.30)
test_data_gen = ImageDataGenerator(rescale = 1./255,validation_split = 0.30)

# %%
training_set = train_data_gen.flow_from_directory(path,
                                                 target_size=(64,64),
                                                 batch_size=100,
                                                 class_mode='categorical',
                                                 shuffle=True,
                                                 color_mode='rgb',
                                                 subset = 'training')

testing_set = test_data_gen.flow_from_directory(path,
                                                 target_size=(64,64),
                                                 batch_size=100,
                                                 class_mode='categorical',
                                                 shuffle=True,
                                                 color_mode='rgb',
                                                 subset = 'validation')
# Out:
# Found 3024 images belonging to 5 classes.
# Found 1293 images belonging to 5 classes.

# %% [markdown]
# # 3.Create Model

# %%
model = Sequential()

# %% [markdown]
# # 4.Add Layers (Convolution,MaxPooling,Flatten,Dense-(Hidden Layers),Output)

# %%
#convolution and Pooling layer 1
model.add(Conv2D(filters=48,kernel_size=3,activation='relu',input_shape=(64,64,3)))
model.add(MaxPool2D(pool_size=2,strides=2))
model.add(Dropout(0.2))

#convolution and Pooling layer 2
model.add(Conv2D(filters=32,kernel_size=3,activation='relu'))
model.add(MaxPool2D(pool_size=2,strides=2))
model.add(Dropout(0.2))

#Flattening the images
model.add(Flatten())

#Fully Connected layers
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(5,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 48)        1344
#
#  max_pooling2d (MaxPooling2D  (None, 31, 31, 48)       0
#  )
#
#  dropout (Dropout)           (None, 31, 31, 48)        0
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 32)        13856
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 14, 14, 32)        0
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 64)                401472
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 416,997
# Trainable params: 416,997
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 5.Compile The Model

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %% [markdown]
# # 6.Fit The Model

# %%
early_stop = EarlyStopping(monitor='val_accuracy', 
                           patience=5,verbose=1,mode='auto')

lr = ReduceLROnPlateau(monitor='val_accuracy', 
                       factor=0.2,patience=5, 
                       min_lr=0.00001)

callback = [early_stop,lr]

# %% [markdown]
# # Training the Model

# %%
result = model.fit(x=training_set, validation_data=testing_set, epochs=50)
# Out:
# Epoch 1/50
# 31/31 [==============================] - 1998s 66s/step - loss: 1.5099 - accuracy: 0.3151 - val_loss: 1.3289 - val_accuracy: 0.4223
# Epoch 2/50
# 31/31 [==============================] - 16s 529ms/step - loss: 1.2896 - accuracy: 0.4269 - val_loss: 1.2464 - val_accuracy: 0.4756
# Epoch 3/50
# 31/31 [==============================] - 16s 526ms/step - loss: 1.1988 - accuracy: 0.4891 - val_loss: 1.1814 - val_accuracy: 0.5104
# Epoch 4/50
# 31/31 [==============================] - 16s 530ms/step - loss: 1.1392 - accuracy: 0.5261 - val_loss: 1.1489 - val_accuracy: 0.5375
# Epoch 5/50
# 31/31 [==============================] - 16s 527ms/step - loss: 1.0944 - accuracy: 0.5675 - val_loss: 1.1114 - val_accuracy: 0.5561
# Epoch 6/50
# 31/31 [==============================] - 16s 528ms/step - loss: 1.0734 - accuracy: 0.5622 - val_loss: 1.0711 - val_accuracy: 0.5746
# Epoch 7/50
# 31/31 [==============================] - 16s 524ms/step - loss: 1.0213 - accuracy: 0.5933 - val_loss: 1.1067 - val_accuracy: 0.5615
# Epoch 8/50
# 31/31 [==============================] - 16s 528ms/step - loss: 1.0087 - accuracy: 0.6124 - val_loss: 1.0906 - val_accuracy: 0.5584
# Epoch 9/50
# 31/31 [==============================] - 16s 528ms/step - loss: 0.9740 - accuracy: 0.6151 - val_loss: 1.0221 - val_accuracy: 0.5955
# Epoch 10/50
# 31/31 [==============================] - 17s 538ms/step - loss: 0.9390 - accuracy: 0.6396 - val_loss: 1.0413 - val_accuracy: 0.5924
# Epoch 11/50
# 31/31 [==============================] - 16s 531ms/step - loss: 0.9273 - accuracy: 0.6429 - val_loss: 0.9696 - val_accuracy: 0.6172
# Epoch 12/50
# 31/31 [==============================] - 16s 531ms/step - loss: 0.8950 - accuracy: 0.6614 - val_loss: 0.9497 - val_accuracy: 0.6381
# Epoch 13/50
# 31/31 [==============================] - 16s 526ms/step - loss: 0.8595 - accuracy: 0.6706 - val_loss: 0.9815 - val_accuracy: 0.6272
# Epoch 14/50
# 31/31 [==============================] - 16s 534ms/step - loss: 0.8512 - accuracy: 0.6763 - val_loss: 1.0239 - val_accuracy: 0.6141
# Epoch 15/50
# 31/31 [==============================] - 16s 531ms/step - loss: 0.8392 - accuracy: 0.6726 - val_loss: 0.9957 - val_accuracy: 0.6164
# Epoch 16/50
# 31/31 [==============================] - 16s 526ms/step - loss: 0.8251 - accuracy: 0.6829 - val_loss: 0.9403 - val_accuracy: 0.6381
# Epoch 17/50
# 31/31 [==============================] - 16s 527ms/step - loss: 0.7930 - accuracy: 0.6905 - val_loss: 0.9704 - val_accuracy: 0.6241
# Epoch 18/50
# 31/31 [==============================] - 16s 530ms/step - loss: 0.7872 - accuracy: 0.7070 - val_loss: 0.9208 - val_accuracy: 0.6589
# Epoch 19/50
# 31/31 [==============================] - 16s 527ms/step - loss: 0.7742 - accuracy: 0.7034 - val_loss: 0.9203 - val_accuracy: 0.6543
# Epoch 20/50
# 31/31 [==============================] - 16s 527ms/step - loss: 0.7386 - accuracy: 0.7199 - val_loss: 0.9309 - val_accuracy: 0.6558
# Epoch 21/50
# 31/31 [==============================] - 16s 534ms/step - loss: 0.7457 - accuracy: 0.7235 - val_loss: 0.9748 - val_accuracy: 0.6326
# Epoch 22/50
# 31/31 [==============================] - 16s 528ms/step - loss: 0.7195 - accuracy: 0.7196 - val_loss: 0.8777 - val_accuracy: 0.6713
# Epoch 23/50
# 31/31 [==============================] - 16s 527ms/step - loss: 0.6985 - accuracy: 0.7308 - val_loss: 0.8767 - val_accuracy: 0.6643
# Epoch 24/50
# 31/31 [==============================] - 16s 526ms/step - loss: 0.7088 - accuracy: 0.7288 - val_loss: 0.8908 - val_accuracy: 0.6659
# Epoch 25/50
# 31/31 [==============================] - 16s 524ms/step - loss: 0.6843 - accuracy: 0.7431 - val_loss: 1.0062 - val_accuracy: 0.6613
# Epoch 26/50
# 31/31 [==============================] - 16s 526ms/step - loss: 0.6916 - accuracy: 0.7259 - val_loss: 0.9222 - val_accuracy: 0.6535
# Epoch 27/50
# 31/31 [==============================] - 16s 526ms/step - loss: 0.6768 - accuracy: 0.7397 - val_loss: 0.9148 - val_accuracy: 0.6674
# Epoch 28/50
# 31/31 [==============================] - 16s 526ms/step - loss: 0.6457 - accuracy: 0.7490 - val_loss: 0.9257 - val_accuracy: 0.6512
# Epoch 29/50
# 31/31 [==============================] - 16s 528ms/step - loss: 0.6403 - accuracy: 0.7573 - val_loss: 0.9018 - val_accuracy: 0.6759
# Epoch 30/50
# 31/31 [==============================] - 16s 530ms/step - loss: 0.6235 - accuracy: 0.7639 - val_loss: 0.9376 - val_accuracy: 0.6674
# Epoch 31/50
# 31/31 [==============================] - 16s 522ms/step - loss: 0.6302 - accuracy: 0.7596 - val_loss: 0.9050 - val_accuracy: 0.6759
# Epoch 32/50
# 31/31 [==============================] - 16s 533ms/step - loss: 0.5861 - accuracy: 0.7774 - val_loss: 0.9466 - val_accuracy: 0.6597
# Epoch 33/50
# 31/31 [==============================] - 17s 541ms/step - loss: 0.6097 - accuracy: 0.7679 - val_loss: 0.8795 - val_accuracy: 0.6752
# Epoch 34/50
# 31/31 [==============================] - 16s 527ms/step - loss: 0.6105 - accuracy: 0.7646 - val_loss: 0.9005 - val_accuracy: 0.6636
# Epoch 35/50
# 31/31 [==============================] - 16s 527ms/step - loss: 0.6251 - accuracy: 0.7583 - val_loss: 0.9376 - val_accuracy: 0.6574
# Epoch 36/50
# 31/31 [==============================] - 16s 524ms/step - loss: 0.5740 - accuracy: 0.7834 - val_loss: 0.9429 - val_accuracy: 0.6806
# Epoch 37/50
# 31/31 [==============================] - 16s 526ms/step - loss: 0.5527 - accuracy: 0.7857 - val_loss: 0.8966 - val_accuracy: 0.6783
# Epoch 38/50
# 31/31 [==============================] - 16s 528ms/step - loss: 0.5568 - accuracy: 0.7897 - val_loss: 0.9474 - val_accuracy: 0.6736
# Epoch 39/50
# 31/31 [==============================] - 16s 524ms/step - loss: 0.5700 - accuracy: 0.7741 - val_loss: 0.9191 - val_accuracy: 0.6837
# Epoch 40/50
# 31/31 [==============================] - 16s 525ms/step - loss: 0.5836 - accuracy: 0.7622 - val_loss: 0.9886 - val_accuracy: 0.6450
# Epoch 41/50
# 31/31 [==============================] - 16s 527ms/step - loss: 0.5502 - accuracy: 0.7976 - val_loss: 0.9613 - val_accuracy: 0.6752
# Epoch 42/50
# 31/31 [==============================] - 16s 534ms/step - loss: 0.5211 - accuracy: 0.8092 - val_loss: 0.8998 - val_accuracy: 0.6976
# Epoch 43/50
# 31/31 [==============================] - 16s 523ms/step - loss: 0.5113 - accuracy: 0.8026 - val_loss: 0.9085 - val_accuracy: 0.6968
# Epoch 44/50
# 31/31 [==============================] - 16s 524ms/step - loss: 0.5143 - accuracy: 0.7950 - val_loss: 0.9276 - val_accuracy: 0.6868
# Epoch 45/50
# 31/31 [==============================] - 16s 528ms/step - loss: 0.4963 - accuracy: 0.8079 - val_loss: 0.9319 - val_accuracy: 0.6744
# Epoch 46/50
# 31/31 [==============================] - 16s 523ms/step - loss: 0.5056 - accuracy: 0.8082 - val_loss: 0.9567 - val_accuracy: 0.6690
# Epoch 47/50
# 31/31 [==============================] - 16s 530ms/step - loss: 0.4930 - accuracy: 0.8161 - val_loss: 0.9988 - val_accuracy: 0.6698
# Epoch 48/50
# 31/31 [==============================] - 16s 526ms/step - loss: 0.4741 - accuracy: 0.8231 - val_loss: 0.9395 - val_accuracy: 0.6775
# Epoch 49/50
# 31/31 [==============================] - 16s 529ms/step - loss: 0.4654 - accuracy: 0.8204 - val_loss: 0.9470 - val_accuracy: 0.6806
# Epoch 50/50
# 31/31 [==============================] - 16s 522ms/step - loss: 0.4664 - accuracy: 0.8155 - val_loss: 0.9465 - val_accuracy: 0.6667

# %% [markdown]
# # Loss and Accuracy check using plot

# %%
#plot the loss
plt.plot(result.history['loss'], label='train loss')
plt.plot(result.history['val_loss'], label='val loss')
plt.legend()
plt.show()

# plot the accuracy
plt.plot(result.history['accuracy'], label='train acc')
plt.plot(result.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()

# %% [markdown]
# # 7.Save the Model

# %%
model.save('flower.h5')

# %% [markdown]
# # 8.Test The Model

# %%
training_set.class_indices
# Out:
# {'daisy': 0, 'dandelion': 1, 'rose': 2, 'sunflower': 3, 'tulip': 4}

# %%
classes = ['Daisy','Dandelion','Rose','Sunflower','Tulip'] 
def testing(img):
    img = image.load_img(img,target_size=(64,64)) 
    x = image.img_to_array(img) 
    x = np.expand_dims(x,axis=0) 
    pred = np.argmax(model.predict(x)) 
    return print("Predicted class as:",classes[pred])

def img_show(img):
    img1 = image.load_img(img,target_size=(64,64)) 
    plt.imshow(img1)

# %%
#test1
img_show('/content/drive/MyDrive/flowers/daisy/10140303196_b88d3d6cec.jpg')
testing('/content/drive/MyDrive/flowers/daisy/10140303196_b88d3d6cec.jpg')
# Out:
# Predicted class as: Daisy

# %%
#test2
img_show('/content/drive/MyDrive/flowers/dandelion/10200780773_c6051a7d71_n.jpg')
testing('/content/drive/MyDrive/flowers/dandelion/10200780773_c6051a7d71_n.jpg')
# Out:
# Predicted class as: Tulip

# %%
#test3
img_show('/content/drive/MyDrive/flowers/rose/10894627425_ec76bbc757_n.jpg')
testing('/content/drive/MyDrive/flowers/rose/10894627425_ec76bbc757_n.jpg')
# Out:
# Predicted class as: Tulip

# %%
#test4
img_show('/content/drive/MyDrive/flowers/sunflower/10386525005_fd0b7d6c55_n.jpg')
testing('/content/drive/MyDrive/flowers/sunflower/10386525005_fd0b7d6c55_n.jpg')
# Out:
# Predicted class as: Tulip

# %%
#test5
img_show('/content/drive/MyDrive/flowers/tulip/100930342_92e8746431_n.jpg')
testing('/content/drive/MyDrive/flowers/tulip/100930342_92e8746431_n.jpg')
# Out:
# Predicted class as: Tulip
