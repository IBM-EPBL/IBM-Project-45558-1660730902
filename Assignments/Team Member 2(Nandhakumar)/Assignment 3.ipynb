# %% [markdown]
# # Importing necessary Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation,Dropout,Conv2D,Flatten,MaxPool2D,Reshape,InputLayer
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img,img_to_array
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %% [markdown]
# # 2.Image Augmentation

# %%
path = '/content/drive/MyDrive/flowers'

# %%
train_data_gen = ImageDataGenerator(rescale = 1./255,
                             shear_range = 0.2,
                             zoom_range = 0.2,
                             horizontal_flip = True,
                             validation_split = 0.30)
test_data_gen = ImageDataGenerator(rescale = 1./255,validation_split = 0.30)

# %%
training_set = train_data_gen.flow_from_directory(path,
                                                 target_size=(64,64),
                                                 batch_size=100,
                                                 class_mode='categorical',
                                                 shuffle=True,
                                                 color_mode='rgb',
                                                 subset = 'training')

testing_set = test_data_gen.flow_from_directory(path,
                                                 target_size=(64,64),
                                                 batch_size=100,
                                                 class_mode='categorical',
                                                 shuffle=True,
                                                 color_mode='rgb',
                                                 subset = 'validation')
# Out:
# Found 3038 images belonging to 5 classes.
# Found 1299 images belonging to 5 classes.

# %% [markdown]
# # 3.Create Model

# %%
model = Sequential()

# %% [markdown]
# # 4.Add Layers (Convolution,MaxPooling,Flatten,Dense-(Hidden Layers),Output)

# %%
#convolution and Pooling layer 1
model.add(Conv2D(filters=48,kernel_size=3,activation='relu',input_shape=(64,64,3)))
model.add(MaxPool2D(pool_size=2,strides=2))
model.add(Dropout(0.2))

#convolution and Pooling layer 2
model.add(Conv2D(filters=32,kernel_size=3,activation='relu'))
model.add(MaxPool2D(pool_size=2,strides=2))
model.add(Dropout(0.2))

#Flattening the images
model.add(Flatten())

#Fully Connected layers
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(5,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 48)        1344
#
#  max_pooling2d (MaxPooling2D  (None, 31, 31, 48)       0
#  )
#
#  dropout (Dropout)           (None, 31, 31, 48)        0
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 32)        13856
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 14, 14, 32)        0
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 64)                401472
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 416,997
# Trainable params: 416,997
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 5.Compile The Model

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %% [markdown]
# # 6.Fit The Model

# %%
early_stop = EarlyStopping(monitor='val_accuracy', 
                           patience=5,verbose=1,mode='auto')

lr = ReduceLROnPlateau(monitor='val_accuracy', 
                       factor=0.2,patience=5, 
                       min_lr=0.00001)

callback = [early_stop,lr]

# %% [markdown]
# # Training the Model

# %%
result = model.fit(x=training_set, validation_data=testing_set, epochs=50)
# Out:
# Epoch 1/50
# 31/31 [==============================] - 667s 21s/step - loss: 1.4439 - accuracy: 0.3433 - val_loss: 1.2856 - val_accuracy: 0.4496
# Epoch 2/50
# 31/31 [==============================] - 17s 548ms/step - loss: 1.2467 - accuracy: 0.4625 - val_loss: 1.2158 - val_accuracy: 0.4796
# Epoch 3/50
# 31/31 [==============================] - 17s 537ms/step - loss: 1.1597 - accuracy: 0.5197 - val_loss: 1.1626 - val_accuracy: 0.5335
# Epoch 4/50
# 31/31 [==============================] - 16s 531ms/step - loss: 1.1143 - accuracy: 0.5513 - val_loss: 1.2158 - val_accuracy: 0.5089
# Epoch 5/50
# 31/31 [==============================] - 16s 534ms/step - loss: 1.0986 - accuracy: 0.5632 - val_loss: 1.1202 - val_accuracy: 0.5558
# Epoch 6/50
# 31/31 [==============================] - 16s 532ms/step - loss: 1.0196 - accuracy: 0.5928 - val_loss: 1.0379 - val_accuracy: 0.5866
# Epoch 7/50
# 31/31 [==============================] - 16s 530ms/step - loss: 0.9894 - accuracy: 0.6119 - val_loss: 1.0176 - val_accuracy: 0.5897
# Epoch 8/50
# 31/31 [==============================] - 16s 530ms/step - loss: 0.9547 - accuracy: 0.6211 - val_loss: 0.9946 - val_accuracy: 0.6097
# Epoch 9/50
# 31/31 [==============================] - 16s 532ms/step - loss: 0.9276 - accuracy: 0.6363 - val_loss: 1.0084 - val_accuracy: 0.6120
# Epoch 10/50
# 31/31 [==============================] - 16s 534ms/step - loss: 0.9040 - accuracy: 0.6435 - val_loss: 1.0044 - val_accuracy: 0.6074
# Epoch 11/50
# 31/31 [==============================] - 16s 528ms/step - loss: 0.8692 - accuracy: 0.6498 - val_loss: 0.9629 - val_accuracy: 0.6320
# Epoch 12/50
# 31/31 [==============================] - 16s 533ms/step - loss: 0.8586 - accuracy: 0.6652 - val_loss: 1.0455 - val_accuracy: 0.6005
# 31/31 [==============================] - 16s 528ms/step - loss: 0.8337 - accuracy: 0.6774 - val_loss: 0.9308 - val_accuracy: 0.6482
# Epoch 14/50
# 31/31 [==============================] - 16s 529ms/step - loss: 0.8121 - accuracy: 0.6959 - val_loss: 0.9287 - val_accuracy: 0.6451
# Epoch 15/50
# 31/31 [==============================] - 16s 523ms/step - loss: 0.8059 - accuracy: 0.6837 - val_loss: 0.9668 - val_accuracy: 0.6228
# Epoch 16/50
# 31/31 [==============================] - 16s 529ms/step - loss: 0.7807 - accuracy: 0.6965 - val_loss: 0.9698 - val_accuracy: 0.6543
# Epoch 17/50
# 31/31 [==============================] - 16s 526ms/step - loss: 0.7744 - accuracy: 0.6949 - val_loss: 0.9867 - val_accuracy: 0.6328
# Epoch 18/50
# 31/31 [==============================] - 16s 533ms/step - loss: 0.7479 - accuracy: 0.7146 - val_loss: 0.9350 - val_accuracy: 0.6590
# Epoch 19/50
# 31/31 [==============================] - 16s 527ms/step - loss: 0.7278 - accuracy: 0.7222 - val_loss: 0.9392 - val_accuracy: 0.6613
# Epoch 20/50
# 31/31 [==============================] - 16s 532ms/step - loss: 0.7477 - accuracy: 0.7166 - val_loss: 0.9041 - val_accuracy: 0.6467
# Epoch 21/50
# 31/31 [==============================] - 17s 543ms/step - loss: 0.7435 - accuracy: 0.7156 - val_loss: 0.9227 - val_accuracy: 0.6405
# Epoch 22/50
# 31/31 [==============================] - 16s 523ms/step - loss: 0.6996 - accuracy: 0.7334 - val_loss: 0.9458 - val_accuracy: 0.6351
# Epoch 23/50
# 31/31 [==============================] - 16s 529ms/step - loss: 0.6762 - accuracy: 0.7423 - val_loss: 0.8607 - val_accuracy: 0.6659
# Epoch 24/50
# 31/31 [==============================] - 16s 531ms/step - loss: 0.6708 - accuracy: 0.7508 - val_loss: 0.8799 - val_accuracy: 0.6528
# Epoch 25/50
# 31/31 [==============================] - 16s 531ms/step - loss: 0.6602 - accuracy: 0.7541 - val_loss: 0.9488 - val_accuracy: 0.6543
# Epoch 26/50
# 31/31 [==============================] - 16s 524ms/step - loss: 0.6445 - accuracy: 0.7518 - val_loss: 0.8840 - val_accuracy: 0.6836
# Epoch 27/50
# 31/31 [==============================] - 16s 535ms/step - loss: 0.6520 - accuracy: 0.7475 - val_loss: 0.8733 - val_accuracy: 0.6767
# Epoch 28/50
# 31/31 [==============================] - 16s 527ms/step - loss: 0.6554 - accuracy: 0.7541 - val_loss: 1.0253 - val_accuracy: 0.6289
# Epoch 29/50
# 31/31 [==============================] - 16s 529ms/step - loss: 0.6342 - accuracy: 0.7633 - val_loss: 0.8829 - val_accuracy: 0.6844
# Epoch 30/50
# 31/31 [==============================] - 16s 523ms/step - loss: 0.6164 - accuracy: 0.7630 - val_loss: 0.8878 - val_accuracy: 0.6674
# Epoch 31/50
# 31/31 [==============================] - 16s 531ms/step - loss: 0.6056 - accuracy: 0.7699 - val_loss: 0.9021 - val_accuracy: 0.6721
# Epoch 32/50
# 31/31 [==============================] - 16s 527ms/step - loss: 0.6058 - accuracy: 0.7666 - val_loss: 0.9192 - val_accuracy: 0.6497
# Epoch 33/50
# 31/31 [==============================] - 16s 532ms/step - loss: 0.5763 - accuracy: 0.7778 - val_loss: 0.9199 - val_accuracy: 0.6690
# Epoch 34/50
# 31/31 [==============================] - 16s 523ms/step - loss: 0.5689 - accuracy: 0.7768 - val_loss: 0.8786 - val_accuracy: 0.6959
# Epoch 35/50
# 31/31 [==============================] - 16s 538ms/step - loss: 0.5767 - accuracy: 0.7788 - val_loss: 0.8534 - val_accuracy: 0.6898
# Epoch 36/50
# 31/31 [==============================] - 16s 529ms/step - loss: 0.5695 - accuracy: 0.7778 - val_loss: 0.9184 - val_accuracy: 0.6790
# Epoch 37/50
# 31/31 [==============================] - 16s 524ms/step - loss: 0.5664 - accuracy: 0.7818 - val_loss: 0.9135 - val_accuracy: 0.6767
# Epoch 38/50
# 31/31 [==============================] - 16s 531ms/step - loss: 0.5409 - accuracy: 0.7900 - val_loss: 0.8503 - val_accuracy: 0.6805
# Epoch 39/50
# 31/31 [==============================] - 16s 531ms/step - loss: 0.5501 - accuracy: 0.8012 - val_loss: 0.8773 - val_accuracy: 0.6851
# Epoch 40/50
# 31/31 [==============================] - 17s 545ms/step - loss: 0.5275 - accuracy: 0.7976 - val_loss: 0.8340 - val_accuracy: 0.6882
# Epoch 41/50
# 31/31 [==============================] - 16s 526ms/step - loss: 0.5083 - accuracy: 0.8117 - val_loss: 0.9672 - val_accuracy: 0.6644
# Epoch 42/50
# 31/31 [==============================] - 16s 531ms/step - loss: 0.5352 - accuracy: 0.8094 - val_loss: 0.9193 - val_accuracy: 0.6844
# Epoch 43/50
# 31/31 [==============================] - 16s 529ms/step - loss: 0.5043 - accuracy: 0.8097 - val_loss: 0.9351 - val_accuracy: 0.6859
# Epoch 44/50
# 31/31 [==============================] - 16s 530ms/step - loss: 0.5030 - accuracy: 0.8097 - val_loss: 0.9108 - val_accuracy: 0.6790
# Epoch 45/50
# 31/31 [==============================] - 16s 532ms/step - loss: 0.4945 - accuracy: 0.8068 - val_loss: 0.9077 - val_accuracy: 0.6828
# Epoch 46/50
# 31/31 [==============================] - 16s 532ms/step - loss: 0.4924 - accuracy: 0.8150 - val_loss: 1.0101 - val_accuracy: 0.6736
# Epoch 47/50
# 31/31 [==============================] - 16s 530ms/step - loss: 0.4889 - accuracy: 0.8097 - val_loss: 0.9092 - val_accuracy: 0.6928
# Epoch 48/50
# 31/31 [==============================] - 16s 531ms/step - loss: 0.4691 - accuracy: 0.8193 - val_loss: 0.9367 - val_accuracy: 0.6952
# Epoch 49/50
# 31/31 [==============================] - 16s 530ms/step - loss: 0.4835 - accuracy: 0.8127 - val_loss: 1.0240 - val_accuracy: 0.6767
# Epoch 50/50
# 31/31 [==============================] - 16s 525ms/step - loss: 0.4576 - accuracy: 0.8193 - val_loss: 0.9656 - val_accuracy: 0.6636

# %% [markdown]
# # Loss and Accuracy check using plot

# %%
#plot the loss
plt.plot(result.history['loss'], label='train loss')
plt.plot(result.history['val_loss'], label='val loss')
plt.legend()
plt.show()

# plot the accuracy
plt.plot(result.history['accuracy'], label='train acc')
plt.plot(result.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()

# %% [markdown]
# # 7.Save the Model

# %%
model.save('flower.h5')

# %% [markdown]
# # 8.Test The Model

# %%
training_set.class_indices
# Out:
# {'daisy': 0, 'dandelion': 1, 'rose': 2, 'sunflower': 3, 'tulip': 4}

# %%
classes = ['Daisy','Dandelion','Rose','Sunflower','Tulip'] 
def testing(img):
    img = image.load_img(img,target_size=(64,64)) 
    x = image.img_to_array(img) 
    x = np.expand_dims(x,axis=0) 
    pred = np.argmax(model.predict(x)) 
    return print("Predicted class as:",classes[pred])

def img_show(img):
    img1 = image.load_img(img,target_size=(64,64)) 
    plt.imshow(img1)

# %%
#test1
img_show('/content/drive/MyDrive/flowers/daisy/10466290366_cc72e33532.jpg')
testing('/content/drive/MyDrive/flowers/daisy/10466290366_cc72e33532.jpg')
# Out:
# Predicted class as: Daisy

# %%
#test2
img_show('/content/drive/MyDrive/flowers/dandelion/10828951106_c3cd47983f.jpg')
testing('/content/drive/MyDrive/flowers/dandelion/10828951106_c3cd47983f.jpg')
# Out:
# Predicted class as: Daisy

# %%
#test3
img_show('//content/drive/MyDrive/flowers/rose/10894627425_ec76bbc757_n.jpg')
testing('/content/drive/MyDrive/flowers/rose/10894627425_ec76bbc757_n.jpg')
# Out:
# Predicted class as: Tulip

# %%
#test4
img_show('/content/drive/MyDrive/flowers/sunflower/10386503264_e05387e1f7_m.jpg')
testing('/content/drive/MyDrive/flowers/sunflower/10386503264_e05387e1f7_m.jpg')
# Out:
# Predicted class as: Sunflower

# %%
#test5
img_show('/content/drive/MyDrive/flowers/tulip/10164073235_f29931d91e.jpg')
testing('/content/drive/MyDrive/flowers/tulip/10164073235_f29931d91e.jpg')
# Out:
# Predicted class as: Tulip
